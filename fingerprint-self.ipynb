# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D, Multiply, Reshape, Layer
from tensorflow.keras.mixed_precision import set_global_policy
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print("GPUs detected:", physical_devices)
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
else:
    print("No GPUs detected. Running on CPU.")

set_global_policy('mixed_float16')

class SelfAttentionLayer(Layer):
    def __init__(self, channel_reduction_factor=16, **kwargs):
        super(SelfAttentionLayer, self).__init__(**kwargs)
        self.channel_reduction_factor = channel_reduction_factor

    def build(self, input_shape):
        channel = input_shape[-1]
        self.query_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.key_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.value_conv = Conv2D(channel, kernel_size=1, padding='same')
        super(SelfAttentionLayer, self).build(input_shape)

    def call(self, inputs):
        batch_size, height, width, channel = tf.shape(inputs)[0], inputs.shape[1], inputs.shape[2], inputs.shape[3]

        query = self.query_conv(inputs)
        key = self.key_conv(inputs)
        value = self.value_conv(inputs)

        query = tf.reshape(query, [batch_size, height * width, channel // self.channel_reduction_factor])
        key = tf.reshape(key, [batch_size, height * width, channel // self.channel_reduction_factor])
        value = tf.reshape(value, [batch_size, height * width, channel])

        attention_scores = tf.matmul(query, key, transpose_b=True)
        scaling_factor = tf.sqrt(tf.cast(channel // self.channel_reduction_factor, inputs.dtype))
        attention_scores = tf.nn.softmax(attention_scores / scaling_factor)

        attention_out = tf.matmul(attention_scores, value)
        attention_out = tf.reshape(attention_out, [batch_size, height, width, channel])

        out = tf.add(inputs, attention_out)
        return out

def efficientnet_b0_plus(input_shape=(224, 224, 3), num_classes=10):
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)
    
    x = base_model.get_layer('block7a_project_bn').output
    x = SelfAttentionLayer(channel_reduction_factor=16)(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='swish')(x)
    output = Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

def mobilenet_plus(input_shape=(224, 224, 3), num_classes=10):
    inputs = tf.keras.Input(shape=input_shape)
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    def inverted_residual_block(x, filters, stride, expansion):
        in_channels = x.shape[-1]
        x_expanded = Conv2D(expansion * in_channels, (1, 1), padding='same')(x)
        x_expanded = layers.BatchNormalization()(x_expanded)
        x_expanded = layers.Activation('relu')(x_expanded)
        
        x_depthwise = layers.DepthwiseConv2D((3, 3), strides=stride, padding='same')(x_expanded)
        x_depthwise = layers.BatchNormalization()(x_depthwise)
        x_depthwise = layers.Activation('relu')(x_depthwise)
        
        x_pointwise = Conv2D(filters, (1, 1), padding='same')(x_depthwise)
        x_pointwise = layers.BatchNormalization()(x_pointwise)
        
        if filters == 128 and stride == 1:
            x = SelfAttentionLayer(channel_reduction_factor=16)(x_pointwise)
        else:
            x = x_pointwise
        
        if stride == 1 and in_channels == filters:
            x = layers.Add()([x, x_pointwise])
        return x
    
    x = inverted_residual_block(x, 64, 1, 6)
    x = inverted_residual_block(x, 128, 2, 6)
    x = inverted_residual_block(x, 128, 1, 6)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    model = Model(inputs=inputs, outputs=output)
    return model

def load_and_preprocess_data(data_dir):
    img_train = np.load(os.path.join(data_dir, 'np_data', 'img_train.npy'))
    label_train = np.load(os.path.join(data_dir, 'np_data', 'label_train.npy'))
    img_real = np.load(os.path.join(data_dir, 'np_data', 'img_real.npy'))
    label_real = np.load(os.path.join(data_dir, 'np_data', 'label_real.npy'))
    
    images = np.concatenate((img_train, img_real), axis=0)
    labels = np.concatenate((label_train, label_real), axis=0)
    
    processed_images = []
    for img in images:
        if len(img.shape) == 2:
            img = np.expand_dims(img, axis=-1)
        if img.shape[-1] == 1:
            img = np.repeat(img, 3, axis=-1)
        img = tf.image.resize(img, [224, 224]).numpy()
        processed_images.append(img)
    
    return np.array(processed_images), labels

if __name__ == "__main__":
    data_dir = '/kaggle/input/fingerprint-dataset-for-fvc2000-db4-b/dataset_FVC2000_DB4_B/dataset'
    images, labels = load_and_preprocess_data(data_dir)
    
    images = images / 255.0
    num_classes = len(np.unique(labels))
    
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
    
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    
    tf.keras.backend.clear_session()
    
    effnet_model = efficientnet_b0_plus(num_classes=num_classes)
    mobilenet_model = mobilenet_plus(num_classes=num_classes)
    
    effnet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    mobilenet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    batch_size = 8
    
    effnet_model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), 
                     epochs=100, 
                     validation_data=(X_test, y_test))
    
    effnet_model.save('effnet_model.h5')
    
    tf.keras.backend.clear_session()
    
    mobilenet_model = mobilenet_plus(num_classes=num_classes)
    mobilenet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    mobilenet_model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), 
                        epochs=100, 
                        validation_data=(X_test, y_test))
    
    mobilenet_model.save('mobilenet_model.h5')
    
    effnet_loss, effnet_acc = effnet_model.evaluate(X_test, y_test)
    mobilenet_loss, mobilenet_acc = mobilenet_model.evaluate(X_test, y_test)
    
    print(f"EfficientNet-B0+ Accuracy: {effnet_acc:.4f}")
    print(f"MobileNet+ Accuracy: {mobilenet_acc:.4f}")
# Out:
# 2025-05-12 13:17:15.705326: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747055835.910128      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747055835.966206      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1747055850.480727      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747055907.663547      59 service.cc:148] XLA service 0x7dc554004f20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747055907.664505      59 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747055912.418486      59 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1747055919.414606      59 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747055919.599142      59 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747055919.992157      59 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747055920.196279      59 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  1/81 ━━━━━━━━━━━━━━━━━━━━ 1:50:21 83s/step - accuracy: 0.1250 - loss: 3.4198
# I0000 00:00:1747055938.878383      59 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 102s 241ms/step - accuracy: 0.2813 - loss: 2.9070 - val_accuracy: 0.0988 - val_loss: 6.7113
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5502 - loss: 1.5563 - val_accuracy: 0.1111 - val_loss: 9.0238
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.4646 - loss: 1.6454 - val_accuracy: 0.0926 - val_loss: 13.6219
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5433 - loss: 1.4358 - val_accuracy: 0.1111 - val_loss: 12.1058
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.5593 - loss: 1.2514 - val_accuracy: 0.0988 - val_loss: 9.1937
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6985 - loss: 0.8965 - val_accuracy: 0.1852 - val_loss: 6.5326
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6517 - loss: 1.1345 - val_accuracy: 0.2531 - val_loss: 3.9284
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6918 - loss: 0.9924 - val_accuracy: 0.3395 - val_loss: 3.7522
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7421 - loss: 0.7933 - val_accuracy: 0.6420 - val_loss: 1.3243
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7807 - loss: 0.7095 - val_accuracy: 0.2099 - val_loss: 3.4229
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7481 - loss: 0.7690 - val_accuracy: 0.5185 - val_loss: 1.9545
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.7326 - loss: 0.8810 - val_accuracy: 0.6111 - val_loss: 1.4715
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8352 - loss: 0.5122 - val_accuracy: 0.8889 - val_loss: 0.6093
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8306 - loss: 0.5716 - val_accuracy: 0.8025 - val_loss: 0.6111
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8280 - loss: 0.5540 - val_accuracy: 0.5432 - val_loss: 2.3333
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7072 - loss: 0.8862 - val_accuracy: 0.6296 - val_loss: 1.0441
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7468 - loss: 0.8457 - val_accuracy: 0.7037 - val_loss: 0.9515
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7909 - loss: 0.6898 - val_accuracy: 0.8951 - val_loss: 0.3185
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.7880 - loss: 0.6469 - val_accuracy: 0.7284 - val_loss: 0.8013
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7625 - loss: 0.7819 - val_accuracy: 0.8395 - val_loss: 0.5301
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7657 - loss: 0.7068 - val_accuracy: 0.7037 - val_loss: 0.9799
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7679 - loss: 0.7032 - val_accuracy: 0.8210 - val_loss: 0.7499
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8629 - loss: 0.4739 - val_accuracy: 0.6790 - val_loss: 1.0787
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8454 - loss: 0.4648 - val_accuracy: 0.8457 - val_loss: 0.4187
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8468 - loss: 0.4222 - val_accuracy: 0.8951 - val_loss: 0.2878
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8689 - loss: 0.3273 - val_accuracy: 0.9383 - val_loss: 0.2234
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8997 - loss: 0.4271 - val_accuracy: 0.9012 - val_loss: 0.2350
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8530 - loss: 0.3768 - val_accuracy: 0.6049 - val_loss: 2.0558
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8417 - loss: 0.5037 - val_accuracy: 0.9753 - val_loss: 0.0895
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9070 - loss: 0.2750 - val_accuracy: 0.9506 - val_loss: 0.2670
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8853 - loss: 0.3546 - val_accuracy: 0.8951 - val_loss: 0.2973
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9297 - loss: 0.2507 - val_accuracy: 0.9568 - val_loss: 0.1628
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9154 - loss: 0.2773 - val_accuracy: 0.7346 - val_loss: 1.5330
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8666 - loss: 0.4125 - val_accuracy: 0.7407 - val_loss: 1.5594
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9069 - loss: 0.3123 - val_accuracy: 0.8395 - val_loss: 0.7592
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8869 - loss: 0.3544 - val_accuracy: 0.8951 - val_loss: 0.4347
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8085 - loss: 0.6754 - val_accuracy: 0.3951 - val_loss: 2.1471
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8020 - loss: 0.6224 - val_accuracy: 0.6975 - val_loss: 1.0748
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8401 - loss: 0.4634 - val_accuracy: 0.8765 - val_loss: 0.4683
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8842 - loss: 0.3773 - val_accuracy: 0.8951 - val_loss: 0.8497
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8921 - loss: 0.3174 - val_accuracy: 0.7963 - val_loss: 1.3064
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 76ms/step - accuracy: 0.8871 - loss: 0.3920 - val_accuracy: 0.8519 - val_loss: 0.3868
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8389 - loss: 0.4641 - val_accuracy: 0.7160 - val_loss: 0.8668
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8966 - loss: 0.3291 - val_accuracy: 0.8025 - val_loss: 0.8772
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8698 - loss: 0.4582 - val_accuracy: 0.8333 - val_loss: 0.7596
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8937 - loss: 0.3861 - val_accuracy: 0.9444 - val_loss: 0.1050
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9111 - loss: 0.3603 - val_accuracy: 0.9753 - val_loss: 0.0852
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9235 - loss: 0.2709 - val_accuracy: 0.5988 - val_loss: 1.5465
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7974 - loss: 0.6239 - val_accuracy: 0.9630 - val_loss: 0.1642
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8924 - loss: 0.3888 - val_accuracy: 0.9938 - val_loss: 0.0212
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9114 - loss: 0.3664 - val_accuracy: 0.7346 - val_loss: 1.0237
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8476 - loss: 0.4789 - val_accuracy: 0.8704 - val_loss: 0.3859
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.7821 - loss: 0.8357 - val_accuracy: 0.4198 - val_loss: 4.2231
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7180 - loss: 0.9428 - val_accuracy: 0.7407 - val_loss: 0.9453
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8457 - loss: 0.5396 - val_accuracy: 0.9691 - val_loss: 0.1228
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8604 - loss: 0.5148 - val_accuracy: 0.8704 - val_loss: 0.3935
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8879 - loss: 0.3719 - val_accuracy: 0.9630 - val_loss: 0.1196
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9110 - loss: 0.2769 - val_accuracy: 0.8889 - val_loss: 0.2650
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8978 - loss: 0.3119 - val_accuracy: 0.8457 - val_loss: 0.5743
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8881 - loss: 0.4175 - val_accuracy: 0.9815 - val_loss: 0.0667
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9314 - loss: 0.1894 - val_accuracy: 0.9877 - val_loss: 0.0278
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9534 - loss: 0.1470 - val_accuracy: 0.9815 - val_loss: 0.0329
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9407 - loss: 0.1694 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9554 - loss: 0.1211 - val_accuracy: 0.9568 - val_loss: 0.2513
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9184 - loss: 0.2570 - val_accuracy: 0.9691 - val_loss: 0.0852
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9730 - loss: 0.1110 - val_accuracy: 0.9630 - val_loss: 0.2097
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9578 - loss: 0.1362 - val_accuracy: 0.9877 - val_loss: 0.0290
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9021 - loss: 0.2712 - val_accuracy: 0.9259 - val_loss: 0.2015
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8941 - loss: 0.2756 - val_accuracy: 0.9444 - val_loss: 0.1502
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8922 - loss: 0.2925 - val_accuracy: 0.9568 - val_loss: 0.1645
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9345 - loss: 0.2153 - val_accuracy: 0.7901 - val_loss: 1.2663
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9345 - loss: 0.2148 - val_accuracy: 0.6543 - val_loss: 4.4047
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9416 - loss: 0.2067 - val_accuracy: 0.8395 - val_loss: 0.8928
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9363 - loss: 0.1610 - val_accuracy: 0.9259 - val_loss: 0.2345
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9263 - loss: 0.2350 - val_accuracy: 0.9815 - val_loss: 0.0759
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9507 - loss: 0.1816 - val_accuracy: 0.8395 - val_loss: 1.0874
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8855 - loss: 0.3674 - val_accuracy: 0.8827 - val_loss: 0.4830
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9189 - loss: 0.2957 - val_accuracy: 0.7099 - val_loss: 1.3587
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8822 - loss: 0.4220 - val_accuracy: 0.8395 - val_loss: 0.4611
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8551 - loss: 0.4800 - val_accuracy: 0.9630 - val_loss: 0.1342
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8684 - loss: 0.4161 - val_accuracy: 0.9815 - val_loss: 0.0505
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.9074 - loss: 0.2440 - val_accuracy: 0.9815 - val_loss: 0.0406
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9537 - loss: 0.1794 - val_accuracy: 0.8765 - val_loss: 0.4130
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9445 - loss: 0.1865 - val_accuracy: 0.8333 - val_loss: 0.6287
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9290 - loss: 0.2739 - val_accuracy: 0.8951 - val_loss: 0.2728
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9250 - loss: 0.2428 - val_accuracy: 0.9198 - val_loss: 0.2090
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8593 - loss: 0.5014 - val_accuracy: 0.3210 - val_loss: 2.4119
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6385 - loss: 1.1540 - val_accuracy: 0.7963 - val_loss: 0.7385
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8087 - loss: 0.5774 - val_accuracy: 0.8457 - val_loss: 0.6595
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8566 - loss: 0.4797 - val_accuracy: 0.8580 - val_loss: 0.7830
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8976 - loss: 0.3712 - val_accuracy: 0.9691 - val_loss: 0.0872
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9143 - loss: 0.2870 - val_accuracy: 0.9630 - val_loss: 0.1353
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9051 - loss: 0.3176 - val_accuracy: 0.9630 - val_loss: 0.1524
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9559 - loss: 0.1887 - val_accuracy: 0.9877 - val_loss: 0.0247
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9404 - loss: 0.1726 - val_accuracy: 0.9506 - val_loss: 0.1500
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9326 - loss: 0.2088 - val_accuracy: 0.9938 - val_loss: 0.0302
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9462 - loss: 0.1899 - val_accuracy: 0.9691 - val_loss: 0.0801
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9437 - loss: 0.1897 - val_accuracy: 0.9136 - val_loss: 0.3700
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9170 - loss: 0.2482 - val_accuracy: 0.9506 - val_loss: 0.1276
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9314 - loss: 0.2070 - val_accuracy: 0.6975 - val_loss: 1.8352
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - accuracy: 0.1734 - loss: 2.3727 - val_accuracy: 0.0988 - val_loss: 2.5296
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.3065 - loss: 1.8156 - val_accuracy: 0.0988 - val_loss: 3.7366
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.3709 - loss: 1.7188 - val_accuracy: 0.0988 - val_loss: 5.8739
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.4412 - loss: 1.5448 - val_accuracy: 0.0988 - val_loss: 7.8429
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.4656 - loss: 1.4205 - val_accuracy: 0.0988 - val_loss: 7.2800
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.4561 - loss: 1.4824 - val_accuracy: 0.0988 - val_loss: 5.9629
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5585 - loss: 1.1936 - val_accuracy: 0.2222 - val_loss: 2.4344
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5279 - loss: 1.2723 - val_accuracy: 0.4815 - val_loss: 1.7653
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5743 - loss: 1.1155 - val_accuracy: 0.2222 - val_loss: 7.2424
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5640 - loss: 1.1752 - val_accuracy: 0.3333 - val_loss: 5.4365
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5892 - loss: 1.1035 - val_accuracy: 0.4444 - val_loss: 1.8788
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5889 - loss: 1.0836 - val_accuracy: 0.2654 - val_loss: 8.4452
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6110 - loss: 1.0278 - val_accuracy: 0.7469 - val_loss: 0.6846
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.6162 - loss: 1.0292 - val_accuracy: 0.2654 - val_loss: 4.5451
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5718 - loss: 1.1327 - val_accuracy: 0.1235 - val_loss: 10.9104
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6343 - loss: 0.9477 - val_accuracy: 0.3148 - val_loss: 4.0043
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6582 - loss: 0.9385 - val_accuracy: 0.2469 - val_loss: 10.5757
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.6377 - loss: 0.9506 - val_accuracy: 0.1975 - val_loss: 18.7779
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5711 - loss: 1.0769 - val_accuracy: 0.3148 - val_loss: 6.1218
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6373 - loss: 0.9546 - val_accuracy: 0.6173 - val_loss: 1.2417
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6601 - loss: 0.9819 - val_accuracy: 0.3519 - val_loss: 5.7534
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6072 - loss: 0.9613 - val_accuracy: 0.7407 - val_loss: 0.7200
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.6771 - loss: 0.9022 - val_accuracy: 0.5309 - val_loss: 1.6085
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6561 - loss: 0.8851 - val_accuracy: 0.5864 - val_loss: 1.7104
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6729 - loss: 0.8361 - val_accuracy: 0.3704 - val_loss: 3.0086
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7253 - loss: 0.8026 - val_accuracy: 0.4630 - val_loss: 2.7852
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7220 - loss: 0.7914 - val_accuracy: 0.4630 - val_loss: 3.4120
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6852 - loss: 0.8362 - val_accuracy: 0.3210 - val_loss: 6.8497
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7451 - loss: 0.7711 - val_accuracy: 0.6543 - val_loss: 1.0268
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6844 - loss: 0.8043 - val_accuracy: 0.1852 - val_loss: 16.9644
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7059 - loss: 0.7629 - val_accuracy: 0.4877 - val_loss: 2.4314
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7585 - loss: 0.7157 - val_accuracy: 0.2778 - val_loss: 6.7442
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7233 - loss: 0.7207 - val_accuracy: 0.1852 - val_loss: 6.8180
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7118 - loss: 0.7693 - val_accuracy: 0.4691 - val_loss: 2.5495
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7087 - loss: 0.7573 - val_accuracy: 0.7160 - val_loss: 0.7343
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.7162 - loss: 0.7243 - val_accuracy: 0.2840 - val_loss: 5.2232
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7407 - loss: 0.7268 - val_accuracy: 0.2716 - val_loss: 8.3301
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7138 - loss: 0.8379 - val_accuracy: 0.2222 - val_loss: 9.9596
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7230 - loss: 0.6802 - val_accuracy: 0.5926 - val_loss: 1.1726
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7089 - loss: 0.7500 - val_accuracy: 0.6914 - val_loss: 1.1651
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7736 - loss: 0.6983 - val_accuracy: 0.5062 - val_loss: 1.9041
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7136 - loss: 0.7717 - val_accuracy: 0.4568 - val_loss: 2.0045
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7021 - loss: 0.7473 - val_accuracy: 0.1914 - val_loss: 9.2506
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7327 - loss: 0.6685 - val_accuracy: 0.2469 - val_loss: 6.1863
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7392 - loss: 0.6535 - val_accuracy: 0.3704 - val_loss: 3.6162
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7180 - loss: 0.7446 - val_accuracy: 0.7901 - val_loss: 0.5830
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7735 - loss: 0.6233 - val_accuracy: 0.6173 - val_loss: 1.1822
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7305 - loss: 0.7868 - val_accuracy: 0.2901 - val_loss: 6.2246
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.7583 - loss: 0.6510 - val_accuracy: 0.8889 - val_loss: 0.3604
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7391 - loss: 0.6880 - val_accuracy: 0.7778 - val_loss: 0.6569
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7234 - loss: 0.6775 - val_accuracy: 0.4630 - val_loss: 2.8725
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7842 - loss: 0.6310 - val_accuracy: 0.3951 - val_loss: 3.0091
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7601 - loss: 0.6128 - val_accuracy: 0.1296 - val_loss: 25.9572
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.7321 - loss: 0.6994 - val_accuracy: 0.1543 - val_loss: 10.8284
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7269 - loss: 0.6265 - val_accuracy: 0.3272 - val_loss: 5.8843
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7721 - loss: 0.6795 - val_accuracy: 0.7284 - val_loss: 0.8182
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7578 - loss: 0.6428 - val_accuracy: 0.7963 - val_loss: 0.5206
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7633 - loss: 0.6578 - val_accuracy: 0.5370 - val_loss: 1.4790
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7837 - loss: 0.6287 - val_accuracy: 0.6543 - val_loss: 1.0003
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7669 - loss: 0.6147 - val_accuracy: 0.6111 - val_loss: 1.2501
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7804 - loss: 0.5365 - val_accuracy: 0.8457 - val_loss: 0.4269
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7375 - loss: 0.6490 - val_accuracy: 0.6667 - val_loss: 1.0809
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7723 - loss: 0.6113 - val_accuracy: 0.7222 - val_loss: 0.8695
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7842 - loss: 0.5623 - val_accuracy: 0.5123 - val_loss: 2.1600
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7741 - loss: 0.6220 - val_accuracy: 0.7654 - val_loss: 0.5754
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7973 - loss: 0.5436 - val_accuracy: 0.5185 - val_loss: 2.0324
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.7992 - loss: 0.5673 - val_accuracy: 0.8210 - val_loss: 0.4238
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7911 - loss: 0.5541 - val_accuracy: 0.1235 - val_loss: 19.0568
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7879 - loss: 0.5061 - val_accuracy: 0.1235 - val_loss: 17.8903
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7621 - loss: 0.6046 - val_accuracy: 0.8519 - val_loss: 0.4451
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8007 - loss: 0.5243 - val_accuracy: 0.4259 - val_loss: 4.5561
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7914 - loss: 0.5470 - val_accuracy: 0.7284 - val_loss: 0.7278
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8330 - loss: 0.4711 - val_accuracy: 0.8272 - val_loss: 0.4896
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8325 - loss: 0.4650 - val_accuracy: 0.2531 - val_loss: 8.0523
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7902 - loss: 0.5304 - val_accuracy: 0.7284 - val_loss: 0.8004
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8143 - loss: 0.4776 - val_accuracy: 0.2099 - val_loss: 15.6659
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7680 - loss: 0.5433 - val_accuracy: 0.2160 - val_loss: 13.6379
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8058 - loss: 0.4933 - val_accuracy: 0.4444 - val_loss: 3.8399
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8255 - loss: 0.4883 - val_accuracy: 0.8333 - val_loss: 0.4606
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8283 - loss: 0.5016 - val_accuracy: 0.3333 - val_loss: 6.7884
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7622 - loss: 0.5827 - val_accuracy: 0.6296 - val_loss: 1.4281
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8319 - loss: 0.4320 - val_accuracy: 0.5556 - val_loss: 2.7452
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7934 - loss: 0.5134 - val_accuracy: 0.4383 - val_loss: 4.0193
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8330 - loss: 0.4519 - val_accuracy: 0.7654 - val_loss: 0.6489
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7788 - loss: 0.5440 - val_accuracy: 0.1235 - val_loss: 20.8435
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8216 - loss: 0.4706 - val_accuracy: 0.4321 - val_loss: 3.0280
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8517 - loss: 0.3860 - val_accuracy: 0.3086 - val_loss: 6.2994
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8040 - loss: 0.4788 - val_accuracy: 0.4938 - val_loss: 2.8924
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8649 - loss: 0.3816 - val_accuracy: 0.5062 - val_loss: 2.7631
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8754 - loss: 0.3477 - val_accuracy: 0.1852 - val_loss: 15.4196
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8384 - loss: 0.4280 - val_accuracy: 0.8333 - val_loss: 0.5522
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8859 - loss: 0.3157 - val_accuracy: 0.2840 - val_loss: 6.5641
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.8627 - loss: 0.4768 - val_accuracy: 0.1049 - val_loss: 37.2678
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8162 - loss: 0.5159 - val_accuracy: 0.6667 - val_loss: 1.0174
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8255 - loss: 0.4611 - val_accuracy: 0.7407 - val_loss: 1.0830
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8597 - loss: 0.4521 - val_accuracy: 0.2037 - val_loss: 11.0283
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8244 - loss: 0.4388 - val_accuracy: 0.7160 - val_loss: 0.8533
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8301 - loss: 0.4020 - val_accuracy: 0.6481 - val_loss: 1.0248
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8613 - loss: 0.4268 - val_accuracy: 0.4877 - val_loss: 3.5759
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8685 - loss: 0.3534 - val_accuracy: 0.8148 - val_loss: 0.4014
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6879 - loss: 1.7851
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8146 - loss: 0.3839
# EfficientNet-B0+ Accuracy: 0.6975
# MobileNet+ Accuracy: 0.8148
