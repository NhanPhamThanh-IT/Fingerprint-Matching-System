# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D, Multiply, Reshape, Layer
from tensorflow.keras.mixed_precision import set_global_policy
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print("GPUs detected:", physical_devices)
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
else:
    print("No GPUs detected. Running on CPU.")

set_global_policy('mixed_float16')

class DualAttentionLayer(Layer):
    def __init__(self, channel_reduction_factor=16, **kwargs):
        super(DualAttentionLayer, self).__init__(**kwargs)
        self.channel_reduction_factor = channel_reduction_factor

    def build(self, input_shape):
        channel = input_shape[-1]
        self.query_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.key_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.value_conv = Conv2D(channel, kernel_size=1, padding='same')
        self.channel_query_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.channel_key_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.channel_value_conv = Conv2D(channel // self.channel_reduction_factor, kernel_size=1, padding='same')
        self.channel_projection = Conv2D(channel, kernel_size=1, padding='same')
        super(DualAttentionLayer, self).build(input_shape)

    def call(self, inputs):
        batch_size, height, width, channel = tf.shape(inputs)[0], inputs.shape[1], inputs.shape[2], inputs.shape[3]

        query = self.query_conv(inputs)
        key = self.key_conv(inputs)
        value = self.value_conv(inputs)

        query = tf.reshape(query, [batch_size, height * width, channel // self.channel_reduction_factor])
        key = tf.reshape(key, [batch_size, height * width, channel // self.channel_reduction_factor])
        value = tf.reshape(value, [batch_size, height * width, channel])

        pos_attention_scores = tf.matmul(query, key, transpose_b=True)
        scaling_factor = tf.sqrt(tf.cast(channel // self.channel_reduction_factor, inputs.dtype))
        pos_attention_scores = tf.nn.softmax(pos_attention_scores / scaling_factor)
        pos_out = tf.matmul(pos_attention_scores, value)
        pos_out = tf.reshape(pos_out, [batch_size, height, width, channel])

        channel_query = self.channel_query_conv(inputs)
        channel_key = self.channel_key_conv(inputs)
        channel_value = self.channel_value_conv(inputs)

        channel_query = tf.reshape(channel_query, [batch_size, height * width, channel // self.channel_reduction_factor])
        channel_key = tf.reshape(channel_key, [batch_size, height * width, channel // self.channel_reduction_factor])
        channel_value = tf.reshape(channel_value, [batch_size, height * width, channel // self.channel_reduction_factor])

        channel_query = tf.transpose(channel_query, perm=[0, 2, 1])
        channel_key = tf.transpose(channel_key, perm=[0, 2, 1])
        channel_value = tf.transpose(channel_value, perm=[0, 2, 1])

        chan_attention_scores = tf.matmul(channel_key, channel_query, transpose_b=True)
        chan_attention_scores = tf.nn.softmax(chan_attention_scores / scaling_factor)
        chan_out = tf.matmul(chan_attention_scores, channel_value)
        chan_out = tf.transpose(chan_out, perm=[0, 2, 1])
        chan_out = tf.reshape(chan_out, [batch_size, height, width, channel // self.channel_reduction_factor])

        chan_out = self.channel_projection(chan_out)

        out = tf.add(pos_out, chan_out)
        out = tf.add(inputs, out)
        return out

def efficientnet_b0_plus(input_shape=(224, 224, 3), num_classes=10):
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)
    
    x = base_model.get_layer('block7a_project_bn').output
    x = DualAttentionLayer(channel_reduction_factor=16)(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='swish')(x)
    output = Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

def mobilenet_plus(input_shape=(224, 224, 3), num_classes=10):
    inputs = tf.keras.Input(shape=input_shape)
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    def inverted_residual_block(x, filters, stride, expansion):
        in_channels = x.shape[-1]
        x_expanded = Conv2D(expansion * in_channels, (1, 1), padding='same')(x)
        x_expanded = layers.BatchNormalization()(x_expanded)
        x_expanded = layers.Activation('relu')(x_expanded)
        
        x_depthwise = layers.DepthwiseConv2D((3, 3), strides=stride, padding='same')(x_expanded)
        x_depthwise = layers.BatchNormalization()(x_depthwise)
        x_depthwise = layers.Activation('relu')(x_depthwise)
        
        x_pointwise = Conv2D(filters, (1, 1), padding='same')(x_depthwise)
        x_pointwise = layers.BatchNormalization()(x_pointwise)
        
        if filters == 128 and stride == 1:
            x = DualAttentionLayer(channel_reduction_factor=16)(x_pointwise)
        else:
            x = x_pointwise
        
        if stride == 1 and in_channels == filters:
            x = layers.Add()([x, x_pointwise])
        return x
    
    x = inverted_residual_block(x, 64, 1, 6)
    x = inverted_residual_block(x, 128, 2, 6)
    x = inverted_residual_block(x, 128, 1, 6)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    model = Model(inputs=inputs, outputs=output)
    return model

def load_and_preprocess_data(data_dir):
    img_train = np.load(os.path.join(data_dir, 'np_data', 'img_train.npy'))
    label_train = np.load(os.path.join(data_dir, 'np_data', 'label_train.npy'))
    img_real = np.load(os.path.join(data_dir, 'np_data', 'img_real.npy'))
    label_real = np.load(os.path.join(data_dir, 'np_data', 'label_real.npy'))
    
    images = np.concatenate((img_train, img_real), axis=0)
    labels = np.concatenate((label_train, label_real), axis=0)
    
    processed_images = []
    for img in images:
        if len(img.shape) == 2:
            img = np.expand_dims(img, axis=-1)
        if img.shape[-1] == 1:
            img = np.repeat(img, 3, axis=-1)
        img = tf.image.resize(img, [224, 224]).numpy()
        processed_images.append(img)
    
    return np.array(processed_images), labels

if __name__ == "__main__":
    data_dir = '/kaggle/input/fingerprint-dataset-for-fvc2000-db4-b/dataset_FVC2000_DB4_B/dataset'
    images, labels = load_and_preprocess_data(data_dir)
    
    images = images / 255.0
    num_classes = len(np.unique(labels))
    
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
    
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    
    tf.keras.backend.clear_session()
    
    effnet_model = efficientnet_b0_plus(num_classes=num_classes)
    mobilenet_model = mobilenet_plus(num_classes=num_classes)
    
    effnet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    mobilenet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    batch_size = 8
    
    effnet_model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), 
                     epochs=100, 
                     validation_data=(X_test, y_test))
    
    effnet_model.save('effnet_model.h5')
    
    tf.keras.backend.clear_session()
    
    mobilenet_model = mobilenet_plus(num_classes=num_classes)
    mobilenet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    mobilenet_model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), 
                        epochs=100, 
                        validation_data=(X_test, y_test))
    
    mobilenet_model.save('mobilenet_model.h5')
    
    effnet_loss, effnet_acc = effnet_model.evaluate(X_test, y_test)
    mobilenet_loss, mobilenet_acc = mobilenet_model.evaluate(X_test, y_test)
    
    print(f"EfficientNet-B0+ Accuracy: {effnet_acc:.4f}")
    print(f"MobileNet+ Accuracy: {mobilenet_acc:.4f}")
# Out:
# 2025-05-12 13:19:43.563321: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747055983.761886      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747055983.823158      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1747055998.060350      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747056057.086756      56 service.cc:148] XLA service 0x79cd3c1afeb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747056057.087742      56 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747056062.043467      56 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1747056069.161288      56 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747056069.346423      56 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747056069.743346      56 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1747056069.948286      56 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  2/81 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.0938 - loss: 3.8984
# I0000 00:00:1747056089.684254      56 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 106s 248ms/step - accuracy: 0.2742 - loss: 2.9198 - val_accuracy: 0.1111 - val_loss: 5.4563
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5360 - loss: 1.5571 - val_accuracy: 0.0988 - val_loss: 9.8574
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5410 - loss: 1.4753 - val_accuracy: 0.0988 - val_loss: 13.4550
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6019 - loss: 1.3932 - val_accuracy: 0.0988 - val_loss: 13.4078
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.5872 - loss: 1.2376 - val_accuracy: 0.1481 - val_loss: 12.6651
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5977 - loss: 1.2112 - val_accuracy: 0.1852 - val_loss: 10.8851
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7555 - loss: 0.7816 - val_accuracy: 0.1914 - val_loss: 11.4996
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7558 - loss: 0.7624 - val_accuracy: 0.3086 - val_loss: 7.1863
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6447 - loss: 1.2082 - val_accuracy: 0.5062 - val_loss: 3.3612
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6745 - loss: 1.0006 - val_accuracy: 0.6852 - val_loss: 1.3096
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8156 - loss: 0.5070 - val_accuracy: 0.8457 - val_loss: 0.5240
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8050 - loss: 0.6398 - val_accuracy: 0.7222 - val_loss: 0.9116
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7537 - loss: 0.8152 - val_accuracy: 0.4321 - val_loss: 4.3462
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7924 - loss: 0.7240 - val_accuracy: 0.6358 - val_loss: 1.6871
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8179 - loss: 0.5294 - val_accuracy: 0.1358 - val_loss: 22.5189
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7171 - loss: 0.8661 - val_accuracy: 0.6173 - val_loss: 3.0749
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.7142 - loss: 1.0842 - val_accuracy: 0.3642 - val_loss: 3.4046
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7439 - loss: 0.7717 - val_accuracy: 0.8765 - val_loss: 0.3959
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7501 - loss: 0.7455 - val_accuracy: 0.7407 - val_loss: 0.7930
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7851 - loss: 0.6281 - val_accuracy: 0.7963 - val_loss: 0.7618
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7760 - loss: 0.6943 - val_accuracy: 0.8272 - val_loss: 0.4832
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8355 - loss: 0.4718 - val_accuracy: 0.9198 - val_loss: 0.2130
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.9109 - loss: 0.2862 - val_accuracy: 0.8951 - val_loss: 0.4419
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9041 - loss: 0.4124 - val_accuracy: 0.8765 - val_loss: 0.4209
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8334 - loss: 0.4675 - val_accuracy: 0.7716 - val_loss: 1.7462
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8330 - loss: 0.6140 - val_accuracy: 0.8827 - val_loss: 0.3766
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8055 - loss: 0.5353 - val_accuracy: 0.8457 - val_loss: 0.4572
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8198 - loss: 0.5636 - val_accuracy: 0.9259 - val_loss: 0.3733
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8701 - loss: 0.4378 - val_accuracy: 0.9074 - val_loss: 1.0856
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8923 - loss: 0.3480 - val_accuracy: 0.9753 - val_loss: 0.0785
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8107 - loss: 0.6928 - val_accuracy: 0.6605 - val_loss: 2.1739
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7573 - loss: 0.8205 - val_accuracy: 0.6358 - val_loss: 1.2723
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6460 - loss: 1.1350 - val_accuracy: 0.7037 - val_loss: 1.0065
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7108 - loss: 0.8432 - val_accuracy: 0.7222 - val_loss: 0.7639
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7635 - loss: 0.7004 - val_accuracy: 0.8210 - val_loss: 0.5613
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7695 - loss: 0.6595 - val_accuracy: 0.8519 - val_loss: 0.3408
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8525 - loss: 0.5266 - val_accuracy: 0.8457 - val_loss: 0.4287
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7915 - loss: 0.5958 - val_accuracy: 0.7963 - val_loss: 0.8210
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8651 - loss: 0.4031 - val_accuracy: 0.8642 - val_loss: 0.4143
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8488 - loss: 0.3819 - val_accuracy: 0.8210 - val_loss: 0.4783
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8267 - loss: 0.5072 - val_accuracy: 0.9074 - val_loss: 0.3162
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7760 - loss: 0.7930 - val_accuracy: 0.9444 - val_loss: 0.1763
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8805 - loss: 0.3716 - val_accuracy: 0.8580 - val_loss: 0.4235
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8575 - loss: 0.4782 - val_accuracy: 0.8148 - val_loss: 0.9817
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8967 - loss: 0.3193 - val_accuracy: 0.7716 - val_loss: 1.1050
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8470 - loss: 0.5115 - val_accuracy: 0.8642 - val_loss: 0.8505
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9140 - loss: 0.2756 - val_accuracy: 0.9877 - val_loss: 0.0484
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9024 - loss: 0.3490 - val_accuracy: 0.9321 - val_loss: 0.2560
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9026 - loss: 0.3143 - val_accuracy: 0.9506 - val_loss: 0.1414
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.9315 - loss: 0.2266 - val_accuracy: 0.9938 - val_loss: 0.0369
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9179 - loss: 0.3052 - val_accuracy: 0.9012 - val_loss: 0.3020
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8318 - loss: 0.5947 - val_accuracy: 0.8827 - val_loss: 0.4681
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9264 - loss: 0.2444 - val_accuracy: 0.9444 - val_loss: 0.1616
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8757 - loss: 0.4269 - val_accuracy: 0.9198 - val_loss: 0.2471
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8905 - loss: 0.3567 - val_accuracy: 0.9321 - val_loss: 0.1985
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9134 - loss: 0.3063 - val_accuracy: 0.7778 - val_loss: 0.9385
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8803 - loss: 0.3889 - val_accuracy: 0.9877 - val_loss: 0.0540
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8902 - loss: 0.3372 - val_accuracy: 0.8457 - val_loss: 0.6195
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.9027 - loss: 0.3487 - val_accuracy: 0.8765 - val_loss: 0.3782
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9238 - loss: 0.2501 - val_accuracy: 0.9630 - val_loss: 0.1294
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9198 - loss: 0.2550 - val_accuracy: 0.8889 - val_loss: 0.4950
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9072 - loss: 0.3791 - val_accuracy: 0.6358 - val_loss: 1.5568
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8762 - loss: 0.4434 - val_accuracy: 0.8951 - val_loss: 0.3880
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9264 - loss: 0.2517 - val_accuracy: 0.9383 - val_loss: 0.1543
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9000 - loss: 0.3621 - val_accuracy: 0.9012 - val_loss: 0.3019
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9549 - loss: 0.1326 - val_accuracy: 0.9630 - val_loss: 0.1368
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8675 - loss: 0.4539 - val_accuracy: 0.3025 - val_loss: 4.2229
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7763 - loss: 0.7602 - val_accuracy: 0.6852 - val_loss: 1.5740
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7805 - loss: 0.7565 - val_accuracy: 0.8519 - val_loss: 0.8872
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8917 - loss: 0.3629 - val_accuracy: 0.8765 - val_loss: 0.4495
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9077 - loss: 0.3532 - val_accuracy: 0.8889 - val_loss: 0.3746
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9277 - loss: 0.2508 - val_accuracy: 0.9198 - val_loss: 0.1504
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.9110 - loss: 0.2725 - val_accuracy: 0.9506 - val_loss: 0.1509
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8927 - loss: 0.3483 - val_accuracy: 0.9383 - val_loss: 0.3393
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9152 - loss: 0.2708 - val_accuracy: 0.9938 - val_loss: 0.0208
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.9337 - loss: 0.2564 - val_accuracy: 0.9136 - val_loss: 0.6959
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8748 - loss: 0.3814 - val_accuracy: 0.7778 - val_loss: 1.1474
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8640 - loss: 0.4670 - val_accuracy: 0.6914 - val_loss: 3.7614
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.9171 - loss: 0.2221 - val_accuracy: 0.7901 - val_loss: 1.6844
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8985 - loss: 0.3175 - val_accuracy: 0.9259 - val_loss: 0.2019
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8751 - loss: 0.4325 - val_accuracy: 0.4321 - val_loss: 4.9087
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8808 - loss: 0.4404 - val_accuracy: 0.4383 - val_loss: 3.5207
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.4575 - loss: 1.9172 - val_accuracy: 0.2037 - val_loss: 3.4500
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.4254 - loss: 1.6954 - val_accuracy: 0.1852 - val_loss: 5.2442
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.3823 - loss: 1.8038 - val_accuracy: 0.3272 - val_loss: 1.9056
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.3850 - loss: 1.6270 - val_accuracy: 0.5370 - val_loss: 1.5501
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5403 - loss: 1.3023 - val_accuracy: 0.3580 - val_loss: 2.5498
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5706 - loss: 1.2427 - val_accuracy: 0.6235 - val_loss: 1.2003
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6460 - loss: 0.9887 - val_accuracy: 0.4630 - val_loss: 2.3525
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6394 - loss: 1.0276 - val_accuracy: 0.4815 - val_loss: 2.0999
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6581 - loss: 1.0972 - val_accuracy: 0.7160 - val_loss: 1.0932
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.7100 - loss: 0.8736 - val_accuracy: 0.4938 - val_loss: 5.5010
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6817 - loss: 0.9164 - val_accuracy: 0.6543 - val_loss: 2.2148
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6896 - loss: 0.8993 - val_accuracy: 0.7284 - val_loss: 0.8580
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6843 - loss: 0.9093 - val_accuracy: 0.8333 - val_loss: 0.4190
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7648 - loss: 0.6432 - val_accuracy: 0.8025 - val_loss: 0.6038
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7753 - loss: 0.6516 - val_accuracy: 0.8519 - val_loss: 0.5157
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7922 - loss: 0.6015 - val_accuracy: 0.8827 - val_loss: 0.3104
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8334 - loss: 0.4966 - val_accuracy: 0.8951 - val_loss: 0.3461
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8302 - loss: 0.4781 - val_accuracy: 0.8704 - val_loss: 0.4294
# Epoch 1/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 33s 145ms/step - accuracy: 0.1706 - loss: 2.4928 - val_accuracy: 0.0988 - val_loss: 2.4424
# Epoch 2/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.2552 - loss: 1.9767 - val_accuracy: 0.0802 - val_loss: 2.8719
# Epoch 3/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.2865 - loss: 1.7817 - val_accuracy: 0.0988 - val_loss: 3.1475
# Epoch 4/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.4019 - loss: 1.6217 - val_accuracy: 0.0988 - val_loss: 3.7655
# Epoch 5/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.3478 - loss: 1.6883 - val_accuracy: 0.0988 - val_loss: 4.6051
# Epoch 6/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.3658 - loss: 1.6153 - val_accuracy: 0.0988 - val_loss: 4.3406
# Epoch 7/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.4544 - loss: 1.4782 - val_accuracy: 0.1790 - val_loss: 4.7694
# Epoch 8/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.4475 - loss: 1.4682 - val_accuracy: 0.3210 - val_loss: 1.8497
# Epoch 9/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.4641 - loss: 1.4052 - val_accuracy: 0.3704 - val_loss: 1.7990
# Epoch 10/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.5177 - loss: 1.3221 - val_accuracy: 0.1358 - val_loss: 17.9225
# Epoch 11/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.4743 - loss: 1.3039 - val_accuracy: 0.3642 - val_loss: 2.3509
# Epoch 12/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5264 - loss: 1.2395 - val_accuracy: 0.1790 - val_loss: 14.2389
# Epoch 13/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5521 - loss: 1.1380 - val_accuracy: 0.1420 - val_loss: 12.7182
# Epoch 14/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.5293 - loss: 1.1874 - val_accuracy: 0.1420 - val_loss: 15.6387
# Epoch 15/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5217 - loss: 1.1990 - val_accuracy: 0.3272 - val_loss: 2.8670
# Epoch 16/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.5769 - loss: 1.1016 - val_accuracy: 0.2593 - val_loss: 7.6067
# Epoch 17/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.5773 - loss: 1.1050 - val_accuracy: 0.1975 - val_loss: 16.3020
# Epoch 18/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.5848 - loss: 1.0727 - val_accuracy: 0.4753 - val_loss: 1.5984
# Epoch 19/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.6298 - loss: 0.9822 - val_accuracy: 0.4198 - val_loss: 2.9045
# Epoch 20/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6481 - loss: 1.0111 - val_accuracy: 0.2284 - val_loss: 7.6332
# Epoch 21/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.5696 - loss: 1.0641 - val_accuracy: 0.5741 - val_loss: 1.0246
# Epoch 22/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6214 - loss: 1.0057 - val_accuracy: 0.6975 - val_loss: 0.7956
# Epoch 23/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.6843 - loss: 0.8770 - val_accuracy: 0.6296 - val_loss: 1.0534
# Epoch 24/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6003 - loss: 0.9840 - val_accuracy: 0.3025 - val_loss: 4.6906
# Epoch 25/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6543 - loss: 0.9519 - val_accuracy: 0.3333 - val_loss: 6.0676
# Epoch 26/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6439 - loss: 0.9018 - val_accuracy: 0.2963 - val_loss: 6.9379
# Epoch 27/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6645 - loss: 0.8676 - val_accuracy: 0.2037 - val_loss: 18.2935
# Epoch 28/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.6953 - loss: 0.8305 - val_accuracy: 0.4691 - val_loss: 2.3950
# Epoch 29/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7063 - loss: 0.8421 - val_accuracy: 0.2160 - val_loss: 10.4469
# Epoch 30/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6768 - loss: 0.8593 - val_accuracy: 0.6667 - val_loss: 0.8696
# Epoch 31/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.6847 - loss: 0.7975 - val_accuracy: 0.7407 - val_loss: 0.6326
# Epoch 32/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.6758 - loss: 0.7946 - val_accuracy: 0.5000 - val_loss: 1.8230
# Epoch 33/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7201 - loss: 0.7558 - val_accuracy: 0.6790 - val_loss: 1.0300
# Epoch 34/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6805 - loss: 0.8274 - val_accuracy: 0.3519 - val_loss: 3.3721
# Epoch 35/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6451 - loss: 0.8910 - val_accuracy: 0.3025 - val_loss: 4.9598
# Epoch 36/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6602 - loss: 0.8624 - val_accuracy: 0.1481 - val_loss: 19.6389
# Epoch 37/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7366 - loss: 0.6775 - val_accuracy: 0.2901 - val_loss: 8.3564
# Epoch 38/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7267 - loss: 0.7646 - val_accuracy: 0.4815 - val_loss: 1.8200
# Epoch 39/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6735 - loss: 0.8512 - val_accuracy: 0.3025 - val_loss: 5.6581
# Epoch 40/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.6431 - loss: 0.8891 - val_accuracy: 0.4321 - val_loss: 3.8722
# Epoch 41/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7256 - loss: 0.7141 - val_accuracy: 0.3272 - val_loss: 3.4922
# Epoch 42/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7265 - loss: 0.7613 - val_accuracy: 0.4815 - val_loss: 2.0662
# Epoch 43/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7052 - loss: 0.7686 - val_accuracy: 0.6111 - val_loss: 1.1102
# Epoch 44/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7548 - loss: 0.6839 - val_accuracy: 0.7963 - val_loss: 0.5004
# Epoch 45/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7343 - loss: 0.6728 - val_accuracy: 0.2778 - val_loss: 5.3060
# Epoch 46/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7826 - loss: 0.5539 - val_accuracy: 0.4444 - val_loss: 5.0464
# Epoch 47/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7284 - loss: 0.7182 - val_accuracy: 0.1481 - val_loss: 19.7934
# Epoch 48/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6898 - loss: 0.7462 - val_accuracy: 0.3395 - val_loss: 4.3006
# Epoch 49/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.6625 - loss: 0.8880 - val_accuracy: 0.2840 - val_loss: 5.7746
# Epoch 50/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.6912 - loss: 0.8000 - val_accuracy: 0.4753 - val_loss: 1.9611
# Epoch 51/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7220 - loss: 0.7224 - val_accuracy: 0.7346 - val_loss: 0.6040
# Epoch 52/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7347 - loss: 0.6665 - val_accuracy: 0.8210 - val_loss: 0.4524
# Epoch 53/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7318 - loss: 0.6658 - val_accuracy: 0.7037 - val_loss: 0.9243
# Epoch 54/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7527 - loss: 0.6331 - val_accuracy: 0.1975 - val_loss: 16.5650
# Epoch 55/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8187 - loss: 0.5674 - val_accuracy: 0.4691 - val_loss: 2.7729
# Epoch 56/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8057 - loss: 0.5372 - val_accuracy: 0.3951 - val_loss: 3.8820
# Epoch 57/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7462 - loss: 0.6012 - val_accuracy: 0.7099 - val_loss: 0.9285
# Epoch 58/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7724 - loss: 0.6230 - val_accuracy: 0.4198 - val_loss: 2.7478
# Epoch 59/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.7837 - loss: 0.5657 - val_accuracy: 0.1728 - val_loss: 14.9007
# Epoch 60/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.7904 - loss: 0.5570 - val_accuracy: 0.3642 - val_loss: 4.5364
# Epoch 61/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8051 - loss: 0.5365 - val_accuracy: 0.6173 - val_loss: 1.3991
# Epoch 62/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7930 - loss: 0.5556 - val_accuracy: 0.5802 - val_loss: 1.5269
# Epoch 63/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7580 - loss: 0.6031 - val_accuracy: 0.5494 - val_loss: 1.8175
# Epoch 64/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.7885 - loss: 0.5502 - val_accuracy: 0.3086 - val_loss: 5.3290
# Epoch 65/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7988 - loss: 0.5704 - val_accuracy: 0.3519 - val_loss: 6.1432
# Epoch 66/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7570 - loss: 0.6481 - val_accuracy: 0.4012 - val_loss: 2.8441
# Epoch 67/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7864 - loss: 0.5641 - val_accuracy: 0.1605 - val_loss: 14.2418
# Epoch 68/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.7709 - loss: 0.5938 - val_accuracy: 0.4198 - val_loss: 3.3860
# Epoch 69/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8216 - loss: 0.5054 - val_accuracy: 0.3210 - val_loss: 5.9245
# Epoch 70/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.7887 - loss: 0.5063 - val_accuracy: 0.2716 - val_loss: 5.5893
# Epoch 71/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.8137 - loss: 0.5081 - val_accuracy: 0.8704 - val_loss: 0.3330
# Epoch 72/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8117 - loss: 0.5256 - val_accuracy: 0.6543 - val_loss: 0.9057
# Epoch 73/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8363 - loss: 0.4514 - val_accuracy: 0.2346 - val_loss: 9.2991
# Epoch 74/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8465 - loss: 0.4297 - val_accuracy: 0.3765 - val_loss: 5.1652
# Epoch 75/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8614 - loss: 0.3439 - val_accuracy: 0.3148 - val_loss: 9.8176
# Epoch 76/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.7982 - loss: 0.5838 - val_accuracy: 0.5123 - val_loss: 2.0339
# Epoch 77/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.8162 - loss: 0.4478 - val_accuracy: 0.5123 - val_loss: 2.6442
# Epoch 78/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8352 - loss: 0.4119 - val_accuracy: 0.8333 - val_loss: 0.5118
# Epoch 79/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 79ms/step - accuracy: 0.8350 - loss: 0.3896 - val_accuracy: 0.7840 - val_loss: 0.7033
# Epoch 80/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8375 - loss: 0.4213 - val_accuracy: 0.2840 - val_loss: 8.6341
# Epoch 81/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.8251 - loss: 0.4831 - val_accuracy: 0.2654 - val_loss: 11.4848
# Epoch 82/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8515 - loss: 0.3896 - val_accuracy: 0.6049 - val_loss: 1.6876
# Epoch 83/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8448 - loss: 0.4054 - val_accuracy: 0.8457 - val_loss: 0.3859
# Epoch 84/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8527 - loss: 0.3849 - val_accuracy: 0.2469 - val_loss: 13.5396
# Epoch 85/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8637 - loss: 0.3861 - val_accuracy: 0.5247 - val_loss: 2.9019
# Epoch 86/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8697 - loss: 0.3551 - val_accuracy: 0.5741 - val_loss: 1.4471
# Epoch 87/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8898 - loss: 0.3910 - val_accuracy: 0.7099 - val_loss: 1.2411
# Epoch 88/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8614 - loss: 0.3822 - val_accuracy: 0.6111 - val_loss: 1.1347
# Epoch 89/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8234 - loss: 0.4756 - val_accuracy: 0.6111 - val_loss: 1.4425
# Epoch 90/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8323 - loss: 0.4729 - val_accuracy: 0.4198 - val_loss: 4.3466
# Epoch 91/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.8966 - loss: 0.3413 - val_accuracy: 0.4815 - val_loss: 2.5843
# Epoch 92/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8604 - loss: 0.3755 - val_accuracy: 0.6358 - val_loss: 1.9705
# Epoch 93/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8608 - loss: 0.3164 - val_accuracy: 0.3827 - val_loss: 6.8456
# Epoch 94/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9112 - loss: 0.2518 - val_accuracy: 0.4877 - val_loss: 3.2507
# Epoch 95/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.9109 - loss: 0.3035 - val_accuracy: 0.7160 - val_loss: 1.0692
# Epoch 96/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8839 - loss: 0.3640 - val_accuracy: 0.7963 - val_loss: 0.5270
# Epoch 97/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.8448 - loss: 0.4049 - val_accuracy: 0.5802 - val_loss: 2.2102
# Epoch 98/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8644 - loss: 0.3873 - val_accuracy: 0.8704 - val_loss: 0.3732
# Epoch 99/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 8s 86ms/step - accuracy: 0.8804 - loss: 0.2795 - val_accuracy: 0.4753 - val_loss: 4.3455
# Epoch 100/100
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.8838 - loss: 0.3356 - val_accuracy: 0.2901 - val_loss: 8.8487
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8501 - loss: 0.4401
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3138 - loss: 8.4074
# EfficientNet-B0+ Accuracy: 0.8704
# MobileNet+ Accuracy: 0.2901
