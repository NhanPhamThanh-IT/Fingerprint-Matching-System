# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D, Multiply, Reshape, Layer
from tensorflow.keras.mixed_precision import set_global_policy
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

physical_devices = tf.config.list_physical_devices('GPU')
if len(physical_devices) > 0:
    print("GPUs detected:", physical_devices)
    for device in physical_devices:
        tf.config.experimental.set_memory_growth(device, True)
else:
    print("No GPUs detected. Running on CPU.")

set_global_policy('mixed_float16')

class SENetLayer(Layer):
    def __init__(self, ratio=16, **kwargs):
        super(SENetLayer, self).__init__(**kwargs)
        self.ratio = ratio

    def build(self, input_shape):
        channel = input_shape[-1]
        self.squeeze = GlobalAveragePooling2D()
        self.excitation = tf.keras.Sequential([
            Dense(channel // self.ratio, activation='relu'),
            Dense(channel, activation='sigmoid')
        ])
        super(SENetLayer, self).build(input_shape)

    def call(self, inputs):
        squeezed = self.squeeze(inputs)
        squeezed = tf.expand_dims(tf.expand_dims(squeezed, 1), 1)
        
        excitation = self.excitation(squeezed)
        
        scaled = Multiply()([inputs, excitation])
        return scaled

def efficientnet_b0_plus(input_shape=(224, 224, 3), num_classes=10):
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=input_shape)
    
    x = base_model.get_layer('block7a_project_bn').output
    x = SENetLayer()(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='swish')(x)
    output = Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    model = Model(inputs=base_model.input, outputs=output)
    return model

def mobilenet_plus(input_shape=(224, 224, 3), num_classes=10):
    inputs = tf.keras.Input(shape=input_shape)
    x = Conv2D(32, (3, 3), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    def inverted_residual_block(x, filters, stride, expansion):
        in_channels = x.shape[-1]
        x_expanded = Conv2D(expansion * in_channels, (1, 1), padding='same')(x)
        x_expanded = layers.BatchNormalization()(x_expanded)
        x_expanded = layers.Activation('relu')(x_expanded)
        
        x_depthwise = layers.DepthwiseConv2D((3, 3), strides=stride, padding='same')(x_expanded)
        x_depthwise = layers.BatchNormalization()(x_depthwise)
        x_depthwise = layers.Activation('relu')(x_depthwise)
        
        x_pointwise = Conv2D(filters, (1, 1), padding='same')(x_depthwise)
        x_pointwise = layers.BatchNormalization()(x_pointwise)
        
        x = SENetLayer()(x_pointwise)
        
        if stride == 1 and in_channels == filters:
            x = layers.Add()([x, x_pointwise])
        return x
    
    x = inverted_residual_block(x, 64, 1, 6)
    x = inverted_residual_block(x, 128, 2, 6)
    x = inverted_residual_block(x, 128, 1, 6)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    output = Dense(num_classes, activation='softmax', dtype='float32')(x)
    
    model = Model(inputs=inputs, outputs=output)
    return model

def load_and_preprocess_data(data_dir):
    img_train = np.load(os.path.join(data_dir, 'np_data', 'img_train.npy'))
    label_train = np.load(os.path.join(data_dir, 'np_data', 'label_train.npy'))
    img_real = np.load(os.path.join(data_dir, 'np_data', 'img_real.npy'))
    label_real = np.load(os.path.join(data_dir, 'np_data', 'label_real.npy'))
    
    images = np.concatenate((img_train, img_real), axis=0)
    labels = np.concatenate((label_train, label_real), axis=0)
    
    processed_images = []
    for img in images:
        if len(img.shape) == 2:
            img = np.expand_dims(img, axis=-1)
        if img.shape[-1] == 1:
            img = np.repeat(img, 3, axis=-1)
        img = tf.image.resize(img, [224, 224]).numpy()
        processed_images.append(img)
    
    return np.array(processed_images), labels

if __name__ == "__main__":
    data_dir = '/kaggle/input/fingerprint-dataset-for-fvc2000-db4-b/dataset_FVC2000_DB4_B/dataset'
    images, labels = load_and_preprocess_data(data_dir)
    
    images = images / 255.0
    num_classes = len(np.unique(labels))
    
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
    
    datagen = ImageDataGenerator(
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True
    )
    
    effnet_model = efficientnet_b0_plus(num_classes=num_classes)
    mobilenet_model = mobilenet_plus(num_classes=num_classes)
    
    effnet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    mobilenet_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    batch_size = 64
    
    effnet_model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), 
                     epochs=100, 
                     validation_data=(X_test, y_test))
    
    mobilenet_model.fit(datagen.flow(X_train, y_train, batch_size=batch_size), 
                        epochs=100, 
                        validation_data=(X_test, y_test))
    
    effnet_loss, effnet_acc = effnet_model.evaluate(X_test, y_test)
    mobilenet_loss, mobilenet_acc = mobilenet_model.evaluate(X_test, y_test)
    
    print(f"EfficientNet-B0+ Accuracy: {effnet_acc:.4f}")
    print(f"MobileNet+ Accuracy: {mobilenet_acc:.4f}")

    effnet_model.save('efficientnet_b0_plus.keras')

    mobilenet_model.save('mobilenet_plus.keras')

    print("Đã lưu các mô hình thành công!")
# Out:
# 2025-05-12 08:25:51.008816: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747038351.211294      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747038351.271977      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1747038366.063459      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747038432.201600      56 service.cc:148] XLA service 0x7ddd5022ae30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747038432.203895      56 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747038438.048279      56 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1747038475.063863      56 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 154s 5s/step - accuracy: 0.2058 - loss: 2.1991 - val_accuracy: 0.0988 - val_loss: 2.7069
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - accuracy: 0.7427 - loss: 0.7726 - val_accuracy: 0.0988 - val_loss: 4.3774
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 277ms/step - accuracy: 0.9096 - loss: 0.2941 - val_accuracy: 0.0988 - val_loss: 5.1087
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9027 - loss: 0.2681 - val_accuracy: 0.0988 - val_loss: 5.7558
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9076 - loss: 0.2557 - val_accuracy: 0.0988 - val_loss: 7.9640
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9106 - loss: 0.2591 - val_accuracy: 0.0988 - val_loss: 4.4535
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 281ms/step - accuracy: 0.9575 - loss: 0.1274 - val_accuracy: 0.1049 - val_loss: 5.0273
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 270ms/step - accuracy: 0.9574 - loss: 0.1391 - val_accuracy: 0.1111 - val_loss: 6.1847
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step - accuracy: 0.9318 - loss: 0.2224 - val_accuracy: 0.0988 - val_loss: 6.2060
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.8967 - loss: 0.4699 - val_accuracy: 0.0988 - val_loss: 16.2533
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9160 - loss: 0.2024 - val_accuracy: 0.0988 - val_loss: 18.7610
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9536 - loss: 0.1604 - val_accuracy: 0.0988 - val_loss: 10.4981
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 277ms/step - accuracy: 0.9572 - loss: 0.1334 - val_accuracy: 0.0988 - val_loss: 6.8978
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 277ms/step - accuracy: 0.9838 - loss: 0.0624 - val_accuracy: 0.0988 - val_loss: 7.2662
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9814 - loss: 0.0581 - val_accuracy: 0.0988 - val_loss: 8.3301
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9684 - loss: 0.0920 - val_accuracy: 0.1790 - val_loss: 6.8710
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 281ms/step - accuracy: 0.9656 - loss: 0.0696 - val_accuracy: 0.1111 - val_loss: 6.6042
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 269ms/step - accuracy: 0.9887 - loss: 0.0247 - val_accuracy: 0.1543 - val_loss: 6.7425
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 219ms/step - accuracy: 0.9788 - loss: 0.0468 - val_accuracy: 0.0494 - val_loss: 9.0907
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.9586 - loss: 0.2024 - val_accuracy: 0.0988 - val_loss: 19.7801
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9581 - loss: 0.1397 - val_accuracy: 0.0556 - val_loss: 7.6465
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - accuracy: 0.9520 - loss: 0.1710 - val_accuracy: 0.0556 - val_loss: 7.5277
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 0.9869 - loss: 0.0896 - val_accuracy: 0.0926 - val_loss: 7.7610
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.9612 - loss: 0.1181 - val_accuracy: 0.0864 - val_loss: 11.6565
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - accuracy: 0.9883 - loss: 0.0335 - val_accuracy: 0.0926 - val_loss: 11.1249
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - accuracy: 0.9867 - loss: 0.0445 - val_accuracy: 0.1049 - val_loss: 11.4125
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 269ms/step - accuracy: 0.9803 - loss: 0.0463 - val_accuracy: 0.0864 - val_loss: 11.8113
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9699 - loss: 0.0773 - val_accuracy: 0.1111 - val_loss: 10.3401
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - accuracy: 0.9632 - loss: 0.1362 - val_accuracy: 0.1235 - val_loss: 8.2829
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9786 - loss: 0.0808 - val_accuracy: 0.1049 - val_loss: 7.4303
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - accuracy: 0.9885 - loss: 0.0524 - val_accuracy: 0.1173 - val_loss: 9.0668
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9950 - loss: 0.0288 - val_accuracy: 0.1173 - val_loss: 9.7511
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 228ms/step - accuracy: 0.9749 - loss: 0.0839 - val_accuracy: 0.1235 - val_loss: 10.2783
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9841 - loss: 0.0552 - val_accuracy: 0.1790 - val_loss: 6.8172
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9664 - loss: 0.0886 - val_accuracy: 0.1852 - val_loss: 6.0132
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - accuracy: 0.9891 - loss: 0.0401 - val_accuracy: 0.1852 - val_loss: 5.6443
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9963 - loss: 0.0183 - val_accuracy: 0.1420 - val_loss: 5.0859
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.9939 - loss: 0.0183 - val_accuracy: 0.1049 - val_loss: 4.8365
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 224ms/step - accuracy: 0.9928 - loss: 0.0266 - val_accuracy: 0.1358 - val_loss: 4.6068
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - accuracy: 0.9973 - loss: 0.0085 - val_accuracy: 0.0988 - val_loss: 4.4408
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9900 - loss: 0.0357 - val_accuracy: 0.1358 - val_loss: 4.2351
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 277ms/step - accuracy: 0.9781 - loss: 0.0978 - val_accuracy: 0.1605 - val_loss: 3.9820
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 267ms/step - accuracy: 0.9895 - loss: 0.0358 - val_accuracy: 0.1605 - val_loss: 4.7558
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.9971 - loss: 0.0200 - val_accuracy: 0.1790 - val_loss: 5.2321
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9872 - loss: 0.0369 - val_accuracy: 0.2222 - val_loss: 5.1264
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.9965 - loss: 0.0171 - val_accuracy: 0.2407 - val_loss: 4.5746
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - accuracy: 0.9948 - loss: 0.0076 - val_accuracy: 0.2469 - val_loss: 4.3124
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9984 - loss: 0.0083 - val_accuracy: 0.2654 - val_loss: 4.5771
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.9759 - loss: 0.0679 - val_accuracy: 0.2160 - val_loss: 6.1144
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 280ms/step - accuracy: 0.9729 - loss: 0.1105 - val_accuracy: 0.1111 - val_loss: 22.2904
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9750 - loss: 0.0953 - val_accuracy: 0.1111 - val_loss: 21.9597
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9777 - loss: 0.0864 - val_accuracy: 0.1111 - val_loss: 18.0723
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9550 - loss: 0.1240 - val_accuracy: 0.1111 - val_loss: 21.4595
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - accuracy: 0.9820 - loss: 0.0644 - val_accuracy: 0.1111 - val_loss: 17.1693
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.9837 - loss: 0.0612 - val_accuracy: 0.1296 - val_loss: 10.0138
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 251ms/step - accuracy: 0.9776 - loss: 0.0998 - val_accuracy: 0.2222 - val_loss: 6.4056
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 234ms/step - accuracy: 0.9459 - loss: 0.2403 - val_accuracy: 0.2160 - val_loss: 5.2186
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 221ms/step - accuracy: 0.9624 - loss: 0.1193 - val_accuracy: 0.3210 - val_loss: 4.0252
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 0.9777 - loss: 0.0720 - val_accuracy: 0.4568 - val_loss: 2.4050
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 280ms/step - accuracy: 0.9912 - loss: 0.0305 - val_accuracy: 0.2963 - val_loss: 4.6227
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 270ms/step - accuracy: 0.9979 - loss: 0.0173 - val_accuracy: 0.2531 - val_loss: 5.1040
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 296ms/step - accuracy: 0.9958 - loss: 0.0163 - val_accuracy: 0.4074 - val_loss: 2.7297
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 282ms/step - accuracy: 0.9945 - loss: 0.0190 - val_accuracy: 0.6358 - val_loss: 1.4385
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.9953 - loss: 0.0132 - val_accuracy: 0.6852 - val_loss: 1.1394
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - accuracy: 0.9969 - loss: 0.0130 - val_accuracy: 0.7222 - val_loss: 0.9255
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 281ms/step - accuracy: 0.9937 - loss: 0.0465 - val_accuracy: 0.7160 - val_loss: 1.0679
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9914 - loss: 0.0293 - val_accuracy: 0.5370 - val_loss: 2.2699
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 215ms/step - accuracy: 0.9855 - loss: 0.0923 - val_accuracy: 0.5617 - val_loss: 1.9191
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 0.9975 - loss: 0.0157 - val_accuracy: 0.4691 - val_loss: 3.1747
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9852 - loss: 0.0358 - val_accuracy: 0.3765 - val_loss: 4.3836
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - accuracy: 0.9906 - loss: 0.0353 - val_accuracy: 0.5062 - val_loss: 2.9584
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.9904 - loss: 0.0555 - val_accuracy: 0.6543 - val_loss: 1.9519
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9862 - loss: 0.0407 - val_accuracy: 0.5864 - val_loss: 2.5140
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - accuracy: 0.9698 - loss: 0.1224 - val_accuracy: 0.5309 - val_loss: 2.5850
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 281ms/step - accuracy: 0.9521 - loss: 0.1424 - val_accuracy: 0.6420 - val_loss: 1.5536
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - accuracy: 0.9868 - loss: 0.0558 - val_accuracy: 0.6914 - val_loss: 1.2171
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 0.9818 - loss: 0.0719 - val_accuracy: 0.6914 - val_loss: 1.1817
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 270ms/step - accuracy: 0.9887 - loss: 0.0263 - val_accuracy: 0.7407 - val_loss: 1.0806
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9881 - loss: 0.0410 - val_accuracy: 0.8272 - val_loss: 0.5364
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9843 - loss: 0.0520 - val_accuracy: 0.8148 - val_loss: 1.0257
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - accuracy: 0.9835 - loss: 0.0720 - val_accuracy: 0.8580 - val_loss: 0.6572
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.9945 - loss: 0.0166 - val_accuracy: 0.8272 - val_loss: 0.7665
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 213ms/step - accuracy: 0.9881 - loss: 0.0335 - val_accuracy: 0.8210 - val_loss: 0.6896
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 0.9960 - loss: 0.0201 - val_accuracy: 0.7901 - val_loss: 0.8052
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 230ms/step - accuracy: 0.9888 - loss: 0.0401 - val_accuracy: 0.7901 - val_loss: 0.6824
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step - accuracy: 0.9923 - loss: 0.0208 - val_accuracy: 0.9074 - val_loss: 0.3540
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - accuracy: 0.9897 - loss: 0.0404 - val_accuracy: 0.9506 - val_loss: 0.1625
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.9953 - loss: 0.0190 - val_accuracy: 0.9753 - val_loss: 0.0526
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 281ms/step - accuracy: 0.9978 - loss: 0.0200 - val_accuracy: 0.9938 - val_loss: 0.0291
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 289ms/step - accuracy: 0.9937 - loss: 0.0137 - val_accuracy: 0.9877 - val_loss: 0.0384
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.9970 - loss: 0.0163 - val_accuracy: 0.9444 - val_loss: 0.1336
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 225ms/step - accuracy: 0.9835 - loss: 0.0524 - val_accuracy: 0.9506 - val_loss: 0.1586
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9937 - loss: 0.0160 - val_accuracy: 0.9753 - val_loss: 0.0662
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - accuracy: 0.9977 - loss: 0.0089 - val_accuracy: 0.9568 - val_loss: 0.1328
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 0.9957 - loss: 0.0115 - val_accuracy: 0.9815 - val_loss: 0.1405
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 269ms/step - accuracy: 0.9956 - loss: 0.0164 - val_accuracy: 0.9877 - val_loss: 0.0444
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 218ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 226ms/step - accuracy: 0.9981 - loss: 0.0078 - val_accuracy: 0.9259 - val_loss: 0.2067
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.9761 - loss: 0.0967 - val_accuracy: 0.9630 - val_loss: 0.1719
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 271ms/step - accuracy: 0.9828 - loss: 0.0593 - val_accuracy: 0.9630 - val_loss: 0.0999
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - accuracy: 0.1688 - loss: 2.1223 - val_accuracy: 0.1173 - val_loss: 2.3054
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 325ms/step - accuracy: 0.3107 - loss: 1.7537 - val_accuracy: 0.1173 - val_loss: 2.3266
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.4298 - loss: 1.4827 - val_accuracy: 0.1173 - val_loss: 2.3791
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.4739 - loss: 1.3813 - val_accuracy: 0.1173 - val_loss: 2.4512
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.4566 - loss: 1.3411 - val_accuracy: 0.1173 - val_loss: 2.5524
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.4857 - loss: 1.3096 - val_accuracy: 0.1173 - val_loss: 2.6649
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.5351 - loss: 1.1560 - val_accuracy: 0.1173 - val_loss: 2.7622
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.5279 - loss: 1.1538 - val_accuracy: 0.1173 - val_loss: 2.9133
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.5720 - loss: 1.0874 - val_accuracy: 0.1173 - val_loss: 3.0377
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - accuracy: 0.5862 - loss: 1.1178 - val_accuracy: 0.1173 - val_loss: 3.1050
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.5985 - loss: 1.0511 - val_accuracy: 0.1173 - val_loss: 3.1800
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 278ms/step - accuracy: 0.6466 - loss: 0.9415 - val_accuracy: 0.1173 - val_loss: 3.2416
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 312ms/step - accuracy: 0.6480 - loss: 0.9700 - val_accuracy: 0.1173 - val_loss: 3.1146
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.6458 - loss: 0.9443 - val_accuracy: 0.0802 - val_loss: 3.3075
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.6264 - loss: 1.0057 - val_accuracy: 0.0802 - val_loss: 3.1597
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.6409 - loss: 0.9408 - val_accuracy: 0.0802 - val_loss: 3.1539
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.6422 - loss: 0.9493 - val_accuracy: 0.0802 - val_loss: 3.2057
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.6840 - loss: 0.9118 - val_accuracy: 0.0802 - val_loss: 3.3205
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.6102 - loss: 0.9482 - val_accuracy: 0.0802 - val_loss: 3.3443
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 311ms/step - accuracy: 0.6583 - loss: 0.8447 - val_accuracy: 0.0802 - val_loss: 3.4339
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 334ms/step - accuracy: 0.6578 - loss: 0.8933 - val_accuracy: 0.1173 - val_loss: 3.3259
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.6689 - loss: 0.8839 - val_accuracy: 0.1111 - val_loss: 3.4214
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 345ms/step - accuracy: 0.6539 - loss: 0.9107 - val_accuracy: 0.1111 - val_loss: 3.6389
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 312ms/step - accuracy: 0.6783 - loss: 0.8246 - val_accuracy: 0.1111 - val_loss: 3.8591
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.6963 - loss: 0.8667 - val_accuracy: 0.1235 - val_loss: 3.9706
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 274ms/step - accuracy: 0.7527 - loss: 0.7103 - val_accuracy: 0.1111 - val_loss: 4.1667
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 327ms/step - accuracy: 0.7115 - loss: 0.7861 - val_accuracy: 0.1173 - val_loss: 4.2837
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.7460 - loss: 0.6785 - val_accuracy: 0.1173 - val_loss: 4.6355
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 326ms/step - accuracy: 0.7311 - loss: 0.7475 - val_accuracy: 0.1111 - val_loss: 4.6234
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.7690 - loss: 0.6621 - val_accuracy: 0.1420 - val_loss: 4.9267
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - accuracy: 0.7948 - loss: 0.6061 - val_accuracy: 0.1296 - val_loss: 5.2548
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.7991 - loss: 0.5420 - val_accuracy: 0.1358 - val_loss: 5.1832
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 301ms/step - accuracy: 0.7428 - loss: 0.6130 - val_accuracy: 0.1358 - val_loss: 5.8066
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 314ms/step - accuracy: 0.8291 - loss: 0.5352 - val_accuracy: 0.1420 - val_loss: 6.3578
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - accuracy: 0.7771 - loss: 0.5665 - val_accuracy: 0.1358 - val_loss: 5.8805
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.7487 - loss: 0.7182 - val_accuracy: 0.1111 - val_loss: 7.3119
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - accuracy: 0.6941 - loss: 0.8282 - val_accuracy: 0.1358 - val_loss: 7.3302
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - accuracy: 0.7554 - loss: 0.6768 - val_accuracy: 0.1543 - val_loss: 7.6483
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.7673 - loss: 0.6405 - val_accuracy: 0.1358 - val_loss: 8.4261
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.7758 - loss: 0.5943 - val_accuracy: 0.2222 - val_loss: 8.1718
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 324ms/step - accuracy: 0.7965 - loss: 0.5189 - val_accuracy: 0.2469 - val_loss: 8.3940
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - accuracy: 0.8112 - loss: 0.5128 - val_accuracy: 0.2222 - val_loss: 7.9416
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 342ms/step - accuracy: 0.8265 - loss: 0.4913 - val_accuracy: 0.2593 - val_loss: 7.8934
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.8373 - loss: 0.4592 - val_accuracy: 0.2284 - val_loss: 8.1793
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.8442 - loss: 0.4306 - val_accuracy: 0.2160 - val_loss: 7.5196
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.8389 - loss: 0.4431 - val_accuracy: 0.2654 - val_loss: 7.3531
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.8755 - loss: 0.3724 - val_accuracy: 0.1975 - val_loss: 7.8806
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.8314 - loss: 0.4566 - val_accuracy: 0.1975 - val_loss: 6.0744
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - accuracy: 0.6231 - loss: 1.1883 - val_accuracy: 0.1667 - val_loss: 14.1373
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.7850 - loss: 0.6401 - val_accuracy: 0.2654 - val_loss: 8.2372
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 276ms/step - accuracy: 0.7667 - loss: 0.6483 - val_accuracy: 0.2716 - val_loss: 5.4307
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 0.7872 - loss: 0.5709 - val_accuracy: 0.2716 - val_loss: 6.0265
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.7986 - loss: 0.5398 - val_accuracy: 0.2593 - val_loss: 5.3556
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 261ms/step - accuracy: 0.8113 - loss: 0.5141 - val_accuracy: 0.3765 - val_loss: 4.6847
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.8232 - loss: 0.4601 - val_accuracy: 0.2407 - val_loss: 4.4597
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 270ms/step - accuracy: 0.8513 - loss: 0.4403 - val_accuracy: 0.3210 - val_loss: 3.1170
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.8525 - loss: 0.4364 - val_accuracy: 0.2778 - val_loss: 3.9458
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.7947 - loss: 0.6208 - val_accuracy: 0.2963 - val_loss: 4.4884
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.8425 - loss: 0.4635 - val_accuracy: 0.3704 - val_loss: 3.4475
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 340ms/step - accuracy: 0.7773 - loss: 0.4879 - val_accuracy: 0.2716 - val_loss: 5.7320
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 268ms/step - accuracy: 0.8806 - loss: 0.3721 - val_accuracy: 0.4568 - val_loss: 2.4246
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.8802 - loss: 0.3313 - val_accuracy: 0.4198 - val_loss: 3.6360
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.8673 - loss: 0.3763 - val_accuracy: 0.2716 - val_loss: 5.5074
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 350ms/step - accuracy: 0.8660 - loss: 0.3570 - val_accuracy: 0.4074 - val_loss: 4.4175
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.9252 - loss: 0.2805 - val_accuracy: 0.4383 - val_loss: 3.6204
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.8938 - loss: 0.3390 - val_accuracy: 0.3210 - val_loss: 4.9937
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.8643 - loss: 0.3507 - val_accuracy: 0.8086 - val_loss: 0.5109
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - accuracy: 0.8787 - loss: 0.3608 - val_accuracy: 0.4753 - val_loss: 3.4534
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.8467 - loss: 0.4058 - val_accuracy: 0.1111 - val_loss: 25.1667
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.8934 - loss: 0.3602 - val_accuracy: 0.2037 - val_loss: 10.4791
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.8711 - loss: 0.3429 - val_accuracy: 0.3704 - val_loss: 4.9967
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 321ms/step - accuracy: 0.8549 - loss: 0.3835 - val_accuracy: 0.2963 - val_loss: 6.5089
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - accuracy: 0.8742 - loss: 0.3535 - val_accuracy: 0.2346 - val_loss: 11.4144
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 334ms/step - accuracy: 0.8607 - loss: 0.3923 - val_accuracy: 0.3025 - val_loss: 4.8842
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 271ms/step - accuracy: 0.8773 - loss: 0.2995 - val_accuracy: 0.2840 - val_loss: 8.0178
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.8600 - loss: 0.4057 - val_accuracy: 0.3086 - val_loss: 6.4168
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.9104 - loss: 0.2719 - val_accuracy: 0.5864 - val_loss: 1.5608
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 329ms/step - accuracy: 0.8737 - loss: 0.3246 - val_accuracy: 0.1728 - val_loss: 50.7088
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 312ms/step - accuracy: 0.8816 - loss: 0.3312 - val_accuracy: 0.1728 - val_loss: 54.0902
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - accuracy: 0.8695 - loss: 0.3255 - val_accuracy: 0.1914 - val_loss: 40.7063
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.9093 - loss: 0.2823 - val_accuracy: 0.1790 - val_loss: 29.2794
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 319ms/step - accuracy: 0.8622 - loss: 0.3848 - val_accuracy: 0.1605 - val_loss: 30.5786
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 330ms/step - accuracy: 0.8915 - loss: 0.3289 - val_accuracy: 0.1852 - val_loss: 23.7087
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.9285 - loss: 0.2793 - val_accuracy: 0.4568 - val_loss: 3.9642
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 263ms/step - accuracy: 0.9021 - loss: 0.2784 - val_accuracy: 0.5309 - val_loss: 2.2060
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.9232 - loss: 0.2298 - val_accuracy: 0.6296 - val_loss: 1.8239
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 331ms/step - accuracy: 0.8864 - loss: 0.3018 - val_accuracy: 0.4259 - val_loss: 3.3461
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 345ms/step - accuracy: 0.9014 - loss: 0.2579 - val_accuracy: 0.4074 - val_loss: 3.6615
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 272ms/step - accuracy: 0.9407 - loss: 0.1967 - val_accuracy: 0.3519 - val_loss: 4.8988
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 320ms/step - accuracy: 0.9288 - loss: 0.2007 - val_accuracy: 0.4074 - val_loss: 3.8934
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step - accuracy: 0.9191 - loss: 0.2433 - val_accuracy: 0.3148 - val_loss: 7.0156
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - accuracy: 0.9097 - loss: 0.2667 - val_accuracy: 0.3827 - val_loss: 5.3075
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 259ms/step - accuracy: 0.9095 - loss: 0.2883 - val_accuracy: 0.2840 - val_loss: 10.3482
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 344ms/step - accuracy: 0.8434 - loss: 0.3880 - val_accuracy: 0.4198 - val_loss: 3.3399
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 269ms/step - accuracy: 0.8975 - loss: 0.3153 - val_accuracy: 0.5432 - val_loss: 1.9477
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.8956 - loss: 0.3271 - val_accuracy: 0.2160 - val_loss: 6.5709
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - accuracy: 0.9178 - loss: 0.2615 - val_accuracy: 0.4691 - val_loss: 2.3393
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 333ms/step - accuracy: 0.8880 - loss: 0.2690 - val_accuracy: 0.6049 - val_loss: 1.5837
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 323ms/step - accuracy: 0.9332 - loss: 0.1932 - val_accuracy: 0.3086 - val_loss: 5.8797
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 317ms/step - accuracy: 0.9314 - loss: 0.2260 - val_accuracy: 0.2037 - val_loss: 16.5007
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9417 - loss: 0.1507
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.1978 - loss: 16.6010
# EfficientNet-B0+ Accuracy: 0.9630
# MobileNet+ Accuracy: 0.2037
# Đã lưu các mô hình thành công!
